# %%
# Import packages
import ee
import geemap
import os
import time
import glob
import time
from osgeo import gdal, gdalconst
import pandas as pd
import numpy as np
import xarray as xr
import rioxarray as rxr
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy.ndimage import binary_opening, binary_closing, generate_binary_structure
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
## DEM READING AND AOI CREATION
 
# Read a SRTM DEM on Guaranda, Bolivar Province (Ecuador)
dem_path = r"C:\Users\Francesco\Python\earthlab\data\Ecuador\DEM\s02_w080_1arc_v3.tif"
dem_img = gdal.Open(dem_path)

if dem_img is None:
    print("The DEM hasn't been read")
else:
    print("DEM opened successfully")
    print('DEM size:', dem_img.RasterXSize, 'x', dem_img.RasterYSize)

# Get the geotransform
dem_gt = dem_img.GetGeoTransform()
print(dem_gt)

# Get the band
dem_band = dem_img.GetRasterBand(1)

# Transform the raster in an array (numpy)
dem_cols = dem_img.RasterXSize
dem_rows = dem_img.RasterYSize
dem_np = dem_band.ReadAsArray(0, 0, dem_cols, dem_rows)

# Mask NoData
dem_nodata_value = dem_band.GetNoDataValue()
print('DEM NoData value:', dem_nodata_value)
dem_np = np.ma.masked_equal(dem_np, dem_nodata_value)

# Get min and max values in the array
print('DEM min value:', np.min(dem_np))
print('DEM max value:', np.max(dem_np))

# Show the DEM
plt.imshow(dem_np, vmin=0, vmax=4143)
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# DEM opened successfully
# DEM size: 3601 x 3601
# (-80.00013888888888, 0.0002777777777777778, 0.0, -0.9998611111111111, 0.0, -0.0002777777777777778)
# DEM NoData value: -32767.0
# DEM min value: -57
# DEM max value: 4143

# %%
# Show the DEM classes <1000, 1000-2000, 3000-4000, >4000
dem_np_cl = dem_np.copy()

dem_np_cl[(dem_np_cl>0) & (dem_np_cl<=1000)] = 1
dem_np_cl[(dem_np_cl>1000) & (dem_np_cl<=2000)] = 2
dem_np_cl[(dem_np_cl>2000) & (dem_np_cl<=2000)] = 3
dem_np_cl[(dem_np_cl>4000)] = 4

plt.figure(figsize=(8, 6))
plt.imshow(dem_np_cl, cmap='terrain')
plt.colorbar(label='Evlevation class')
plt.title('Classefied DEM Bolivar Province (Ecuador)')
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Calculate the DEM bounding box
xmin = dem_gt[0]
ymin = dem_gt[3]
xmax = dem_gt[0] + dem_cols*dem_gt[1]
ymax = dem_gt[3] + dem_rows*dem_gt[5]
print("Bounding Box: ", f"xmin: {xmin}, ymin: {ymin}, xmax: {xmax}, ymax: {ymax}")

# Use Google Earth Engine
ee.Authenticate()
ee.Initialize()

# Create the aoi
aoi = ee.Geometry.Rectangle([xmin, ymin, xmax, ymax])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Bounding Box:  xmin: -80.00013888888888, ymin: -0.9998611111111111, xmax: -78.9998611111111, ymax: -2.000138888888889

# %%
## MODIS NDVI COLLECTION

# Get the modis images for the dry season in the aoi
start_date = '2025-05-01'
end_date = '2025-10-01'
modis = ee.ImageCollection('MODIS/061/MOD09GA').filterBounds(aoi).filterDate(start_date, end_date)

# QA Mask function
def mask_modis(image):

    state = image.select('state_1km')
    cloud_state = state.bitwiseAnd(0b11 << 0).rightShift(0)
    cloud_shadow = state.bitwiseAnd(0b1 << 2).rightShift(2)
    land_water = state.bitwiseAnd(0b111 << 3).rightShift(3)

    qc = image.select('QC_500m')
    modland = qc.bitwiseAnd(0b11 << 0).rightShift(0)

    mask = cloud_state.eq(0).And(cloud_shadow.eq(0)).And(land_water.eq(1)).And(modland.eq(0))

    return image.updateMask(mask)

# Create and add the NDVI band + valid pixels (pixels with ndvi!=0)
def add_ndvi(image):

    ndvi = image.normalizedDifference(['sur_refl_b02', 'sur_refl_b01']).rename('NDVI')

    valid_pixels = ndvi.mask().reduceRegion(reducer = ee.Reducer.count(),
                                            geometry = aoi,
                                            scale = 500,
                                            maxPixels = 1e13).get('NDVI') # the reduceRegion() gives a ditionary as a result: {'ndvi': n.ofValidPixels}. The get('ndvi') takes the value of 'ndvi' from a dictionary and converts it in a number

    return image.addBands(ndvi).set('valid_pixels', valid_pixels) # the valid_pixels is stored as a metadata on the image

modis_clean_ndvi = modis.map(mask_modis).map(add_ndvi)

# Reduce to NDVI mean + valid pixels
def get_mean(image):
    
    mean_dict = image.select('NDVI').reduceRegion(reducer = ee.Reducer.mean(),
                                                  geometry = aoi,
                                                  scale = 500,
                                                  maxPixels = 1e13) # stats is a dictionary
    
    return ee.Feature(None, #no geometry
                      {'date': image.date().format('YYYY-MM-dd'),
                       'NDVI': mean_dict.get('NDVI'),
                       'valid_pixels': image.get('valid_pixels'),
                       'id': image.id()})

ndvi_fc = modis_clean_ndvi.map(get_mean)

# Convert to Pandas DataFrame
ndvi_list = ndvi_fc.getInfo()['features'] # pulls the data to the Python dictionary, accessing the list of features in the FeatureCollection

data = [(f['properties'].get('date'), # for each feature it extract the value of 'date', 'NDVI', ...
         f['properties'].get('NDVI'),
         f['properties'].get('valid_pixels'),
         f.get('id')) 
        for f in ndvi_list
        if f['properties'].get('NDVI') is not None]

ndvi_df = pd.DataFrame(data, columns=['date', 'NDVI', 'valid_pixels', 'id'])
ndvi_df['date'] = pd.to_datetime(ndvi_df['date'])
ndvi_df['NDVI'] = pd.to_numeric(ndvi_df['NDVI'])
ndvi_df['valid_pixels'] = pd.to_numeric(ndvi_df['valid_pixels'])
ndvi_df = ndvi_df.dropna().sort_values('date') # remove missing ndvi values and sort by date

# Filter by valid pixels (eliminate those images where the number of valid pixels is less than 30% of the maximum valid pixel number between the images). This makes the time series more reliable
max_valid = ndvi_df['valid_pixels'].max()
threshold = 0.3 * max_valid
ndvi_df = ndvi_df[ndvi_df['valid_pixels'] >= threshold]

# Outlier removal
Q1 = ndvi_df['NDVI'].quantile(0.25)
Q3 = ndvi_df['NDVI'].quantile(0.75)
IQR = Q3 - Q1
lower_outlier_limit = Q1 - 1.5*IQR
upper_outlier_limit = Q3 + 1.5*IQR

ndvi_clean = ndvi_df[(ndvi_df['NDVI'] >= lower_outlier_limit) & (ndvi_df['NDVI'] <= upper_outlier_limit)]

# Plot clean NDVI time series
plt.figure(figsize=(12, 5))
plt.plot(ndvi_clean['date'], ndvi_clean['NDVI'], marker='o', linestyle='-')
plt.title('Cleaned Dry Season MODIS mean NDVI Time Series - Guaranda 2025')
plt.xlabel('Date')
plt.ylabel('Mean NDVI')
plt.grid(True)
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Check the min/max values in GEE for the ImageCollection before exporting them
min_val = modis_clean_ndvi.min().reduceRegion(
    reducer=ee.Reducer.min(),
    geometry=aoi,
    scale=500
).get('NDVI').getInfo()

max_val = modis_clean_ndvi.max().reduceRegion(
    reducer=ee.Reducer.max(),
    geometry=aoi,
    scale=500
).get('NDVI').getInfo()

print(f"Expected NDVI range in GEE: {min_val} to {max_val}")

# Check the stats of one image in the ImageCollection
sample_img = ee.Image(modis_clean_ndvi.first()).select('NDVI')
stats = sample_img.reduceRegion(reducer=ee.Reducer.minMax(),
                                geometry=aoi,
                                scale=500)
print(stats.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Expected NDVI range in GEE: -0.5427631735801697 to 1
# {'NDVI_max': 0.9121651295564339, 'NDVI_min': -0.3916083916083916}

# %%
# Export each clean NDVI image to local GEOTiffs
output_dir = r"C:\Users\Francesco\Python\earthlab\data\Ecuador\NDVI"
os.makedirs(output_dir, exist_ok=True)

modis_list = modis_clean_ndvi.toList(modis_clean_ndvi.size()) # create the list of images in python from the ImageCollactiion in GEE (I need to specify how many images to include)
n = modis_clean_ndvi.size().getInfo() # get the value of the number of images in the collection

for i in range(n):
    
    img = ee.Image(modis_list.get(i)).select('NDVI').toFloat() # get the image ensuring it has Float values (this is necessary to doesn't make any changes to theur values during the export)
    img = img.updateMask(img.gte(-1)).updateMask(img.lte(1)) # mask masked or invalid pixels which, if not masked, would be treated as numeric
    img = img.unmask(-9999) # Fill masked pixels with -9999 explicitly

    date_ms = img.get('system:time_start').getInfo() # get the date value of the image
    date_str = pd.to_datetime(date_ms, unit='ms').strftime('%Y%m%d') # make the date in a data format like 20250501

    out_name = f'NDVI_{date_str}.tif'
    out_path = os.path.join(output_dir, out_name)

    try: 
        geemap.ee_export_image(img,
                               filename=out_path,
                               scale=500,
                               region=aoi,
                               file_per_band=False)
        # Add metadata with nodata value explicitly
        with rasterio.open(out_path, 'r+') as dst:
            dst.nodata = -9999
        print(f'Saved: {out_name}')
        time.sleep(10) # pause to avoid throttling
    except Exception as e:
        print(f'Failed: {out_name}, {e}')

# %%
# Check exported NDVI

path = r"C:\Users\Francesco\Python\earthlab\data\Ecuador\NDVI\NDVI_20250501.tif"

with rasterio.open(path) as src:
    print("Unique nodata value in metadata:", src.nodata)
    ndvi = src.read(1)
    print("Any NaN?", np.isnan(ndvi).any())
    print("Any inf?", np.isinf(ndvi).any())
    print("NDVI stats ignoring inf/nan:")
    ndvi = np.where(ndvi == src.nodata, np.nan, ndvi)
    print("NDVI min/max ignoring nodata:", np.nanmin(ndvi), np.nanmax(ndvi))

output_dir = r"C:\Users\Francesco\Python\earthlab\data\Ecuador\NDVI"
files = [f for f in os.listdir(output_dir) if f.endswith('.tif')]

for f in files:
    path = os.path.join(output_dir, f)
    with rasterio.open(path) as src:
        ndvi = src.read(1)  # Read the first (and only) band
        nodata = src.nodata
        # Check basic statistics
        print(f"\nFile: {f}")
        print(f"Shape: {ndvi.shape}")
        print(f"Min: {np.min(ndvi)}, Max: {np.max(ndvi)}, Mean: {np.mean(ndvi):.3f}")
        
        # Mask nodata values
        if nodata is not None:
            ndvi = np.where(ndvi == nodata, np.nan, ndvi)
        
        # Compute stats ignoring nodata
        valid = np.isfinite(ndvi)
        print(f"Valid pixel count: {np.sum(valid)}")
        if np.any(valid):
            print(f"Min: {np.nanmin(ndvi)}, Max: {np.nanmax(ndvi)}, Mean: {np.nanmean(ndvi):.3f}")
        else:
            print("No valid pixels")
        
        # NDVI range sanity check
        if np.any((ndvi < -1) & valid) or np.any((ndvi > 1) & valid):
            print("Warning: NDVI values out of expected range [-1, 1]")
        else:
            print("All NDVI values within expected range [-1, 1]")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Unique nodata value in metadata: -9999.0
# Any NaN? False
# Any inf? False
# NDVI stats ignoring inf/nan:
# NDVI min/max ignoring nodata: -0.3916084 0.9121651
#
# File: NDVI_20250501.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.912165105342865, Mean: -8597.129
# Valid pixel count: 7253
# Min: -0.3916083872318268, Max: 0.912165105342865, Mean: 0.614
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250502.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.9335923790931702, Mean: -9749.088
# Valid pixel count: 1293
# Min: -0.10864073038101196, Max: 0.9335923790931702, Mean: 0.553
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250503.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.9115329384803772, Mean: -9762.614
# Valid pixel count: 1223
# Min: 0.05839838087558746, Max: 0.9115329384803772, Mean: 0.736
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250504.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.9419087171554565, Mean: -9446.789
# Valid pixel count: 2857
# Min: 0.042205262929201126, Max: 0.9419087171554565, Mean: 0.708
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250505.tif
# Shape: (223, 232)
# Min: -9999.0, Max: -9999.0, Mean: -9999.000
# Valid pixel count: 0
# No valid pixels
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250506.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.9183031916618347, Mean: -7617.950
# Valid pixel count: 12319
# Min: -0.31522515416145325, Max: 0.9183031916618347, Mean: 0.675
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250507.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.993574321269989, Mean: -6953.657
# Valid pixel count: 15756
# Min: -0.3239104747772217, Max: 0.993574321269989, Mean: 0.612
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250508.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.8653568625450134, Mean: -9980.832
# Valid pixel count: 94
# Min: 0.1868821531534195, Max: 0.8653568625450134, Mean: 0.557
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250509.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.9319984912872314, Mean: -4398.251
# Valid pixel count: 28977
# Min: -0.5427631735801697, Max: 0.9319984912872314, Mean: 0.667
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250510.tif
# Shape: (223, 232)
# Min: -9999.0, Max: -9999.0, Mean: -9999.000
# Valid pixel count: 0
# No valid pixels
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250511.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.7866795659065247, Mean: -9978.705
# Valid pixel count: 105
# Min: 0.18829897046089172, Max: 0.7866795659065247, Mean: 0.622
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250512.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.8373205661773682, Mean: -9988.370
# Valid pixel count: 55
# Min: 0.2083950638771057, Max: 0.8373205661773682, Mean: 0.374
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250513.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250916.tif
# Shape: (223, 232)
# Min: -9999.0, Max: -9999.0, Mean: -9999.000
# Valid pixel count: 0
# No valid pixels
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250917.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.8654654622077942, Mean: -9981.991
# Valid pixel count: 88
# Min: 0.17641301453113556, Max: 0.8654654622077942, Mean: 0.575
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250918.tif
# Shape: (223, 232)
# Min: -9999.0, Max: -9999.0, Mean: -9999.000
# Valid pixel count: 0
# No valid pixels
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250919.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.7280809879302979, Mean: -9983.537
# Valid pixel count: 80
# Min: 0.32774752378463745, Max: 0.7280809879302979, Mean: 0.519
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250920.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.7997317910194397, Mean: -9903.712
# Valid pixel count: 493
# Min: 0.2182103544473648, Max: 0.7997317910194397, Mean: 0.618
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250921.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.7559905052185059, Mean: -9981.411
# Valid pixel count: 91
# Min: 0.4012789726257324, Max: 0.7559905052185059, Mean: 0.534
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250922.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.8661576509475708, Mean: -8307.591
# Valid pixel count: 8751
# Min: 0.06362424790859222, Max: 0.8661576509475708, Mean: 0.626
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250923.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.9983659982681274, Mean: -8814.562
# Valid pixel count: 6128
# Min: 0.012225518934428692, Max: 0.9983659982681274, Mean: 0.688
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250924.tif
# Shape: (223, 232)
# Min: -9999.0, Max: -9999.0, Mean: -9999.000
# Valid pixel count: 0
# No valid pixels
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250925.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.9322637915611267, Mean: -6405.704
# Valid pixel count: 18591
# Min: 0.02727545239031315, Max: 0.9322637915611267, Mean: 0.612
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250926.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.8267716765403748, Mean: -9955.512
# Valid pixel count: 225
# Min: 0.39187347888946533, Max: 0.8267716765403748, Mean: 0.603
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250927.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.7857656478881836, Mean: -9543.056
# Valid pixel count: 2359
# Min: 0.029215017333626747, Max: 0.7857656478881836, Mean: 0.467
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250928.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.984329104423523, Mean: -9312.463
# Valid pixel count: 3552
# Min: 0.014183240942656994, Max: 0.984329104423523, Mean: 0.620
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250929.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.8838232755661011, Mean: -9026.219
# Valid pixel count: 5033
# Min: 0.1503489911556244, Max: 0.8838232755661011, Mean: 0.566
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_20250930.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.8931204080581665, Mean: -9415.104
# Valid pixel count: 3021
# Min: 0.005404342897236347, Max: 0.8931204080581665, Mean: 0.499
# All NDVI values within expected range [-1, 1]
#
# File: NDVI_stack.tif
# Shape: (223, 232)
# Min: -9999.0, Max: 0.912165105342865, Mean: -8597.129
# Valid pixel count: 7253
# Min: -0.3916083872318268, Max: 0.912165105342865, Mean: 0.614
# All NDVI values within expected range [-1, 1]

# %%
# Merge NDVI GEOTiffs into a multi-band stack file

tif_folder = r"C:\Users\Francesco\Python\earthlab\data\Ecuador\NDVI"
tif_list = sorted(glob.glob(os.path.join(tif_folder, 'NDVI_*.tif')))

if len(tif_list) == 0:
    raise FileNotFoundError('No NDVI_*.tif files found in the specific folder')

# Create output file
merged_tif = os.path.join(tif_folder, 'NDVI_stack.tif')

# Read all files with nodata awareness
bands = []
for path in tif_list:
    with rasterio.open(path) as src:
        arr = src.read(1).astype(np.float32)
        nodata = src.nodata if src.nodata is not None else -9999
        arr = np.where(arr == nodata, nodata, arr) # Mask out nodata
        bands.append(arr)

# Stack all the NDVI bands
ndvi_stack = np.stack(bands, axis=0)

# Get the georeference info from the first image
ref_ds = gdal.Open(tif_list[0], gdal.GA_ReadOnly)
driver = gdal.GetDriverByName('GTiff')
out_ds = driver.Create(merged_tif,
                       ref_ds.RasterXSize,
                       ref_ds.RasterYSize,
                       len(tif_list),
                       gdalconst.GDT_Float32)
out_ds.SetGeoTransform(ref_ds.GetGeoTransform())
out_ds.SetProjection(ref_ds.GetProjection())

# Write each NDVI image as a new band
for i, ndvi_band in enumerate(ndvi_stack):
    out_band = out_ds.GetRasterBand(i+1)
    # Replace NaN with -9999 for storage
    ndvi_band_filled = np.where(np.isnan(ndvi_band), -9999, ndvi_band)
    out_band.WriteArray(ndvi_band_filled)
    date = os.path.basename(tif_list[i].replace('NDVI', '').replace('.tif', ''))
    out_band.SetDescription(date)
    out_band.SetNoDataValue(-9999)

out_ds.FlushCache()
out_ds = None
print(f'Multi-band stack NDVI created at: {merged_tif}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Multi-band stack NDVI created at: C:\Users\Francesco\Python\earthlab\data\Ecuador\NDVI\NDVI_stack.tif

# %%
# Export to NetCDF

# Extracts dates from filenames
dates = [os.path.basename(f).split('_')[1].split('.')[0] for f in tif_list]
dates = pd.to_datetime(dates, format='%Y%m%d')

# Convert NDVI stack to xarray dataset
da = xr.DataArray(ndvi_stack,
                  dims = ['time', 'y', 'x'],
                  coords = {'time': dates},
                  name = 'NDVI')
ds = xr.Dataset({'NDVI': da})

netcdf_path = os.path.join(tif_folder, 'NDVI_stack.nc')
ds.to_netcdf(netcdf_path)
print(f'The NetCDF NDVI stack is saved at: {netcdf_path}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The NetCDF NDVI stack is saved at: C:\Users\Francesco\Python\earthlab\data\Ecuador\NDVI\NDVI_stack.nc

# %%
# Plot the NDVI time series for a pixel

ndvi = rxr.open_rasterio(merged_tif, masked=True).astype(float)
ndvi = ndvi.where(ndvi != -9999)
print(f"NDVI stack range: {np.nanmin(ndvi.values):.3f} to {np.nanmax(ndvi.values):.3f}")
print(f"Bands: {ndvi.sizes['band']}, Dates: {len(dates)}")

# Assign the time coordinate to the 'band' dimension (the xarray.DataArray ndvi has three dimensions (band: n° of images, y, x))
ndvi = ndvi.assign_coords(time=('band', dates)).swap_dims({'band':'time'})

# Coordinates to analyse
lon, lat = -79.026681, -1.578568

pixel_ts = ndvi.sel(x=lon, y=lat, method='nearest')
# Drop NaNs (in case of masked frames)
pixel_ts = pixel_ts.where(np.isfinite(pixel_ts), drop=True)

print('NDVI values', pixel_ts.values)
print("Mean NDVI:", np.nanmean(pixel_ts.values))

plt.figure(figsize=(10, 5))
plt.plot(pixel_ts['time'], pixel_ts.values, marker='o')
plt.title(f'NDVI time series at: {lon}, {lat}')
plt.xlabel('Date')
plt.ylabel('NDVI')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# NDVI stack range: -0.543 to 1.000
# Bands: 153, Dates: 153
# NDVI values [0.12310512 0.40273312 0.69747901 0.46538186 0.44442651 0.62848896
#  0.64555258 0.61238885 0.54279196 0.67544174 0.61090809 0.04918929
#  0.52355915 0.68861026 0.2341827  0.64140481 0.55712533 0.08847249
#  0.52028471 0.55867732 0.20115356 0.53772223 0.56905276 0.35236666
#  0.57896698 0.54477906 0.53175002 0.53312302 0.51590037 0.65567011
#  0.1367611  0.55195558 0.53846157 0.69796813 0.49916458 0.75760931
#  0.31612718]
# Mean NDVI: 0.4926685416013808

# %%
# Smoothe (reduce noise from cloud contamination or residual masking issues) with a moving average to reveal underlying vegetation trend better
smoothed_ndvi = pd.Series(pixel_ts.values, index=pixel_ts['time'].values).rolling(window=3, center=True).mean()
plt.plot(pixel_ts['time'], smoothed_ndvi, marker='o')
plt.title(f'NDVI time series at: {lon}, {lat}')
plt.xlabel('Date')
plt.ylabel('NDVI')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# PIXEL-WISE NDVI TREND SLOPE ANALYSIS

# Get the days in the time period (e.g. 0, 1, 2, ..., n_time-1)
time_numeric = np.arange(ndvi.shape[0])

# Mask nodata
ndvi_masked = np.where(ndvi.values == -9999, np.nan, ndvi.values)

# Reshape for easier math
T, Y, X = ndvi_masked.shape
ndvi_reshaped = ndvi_masked.reshape(T, -1) # I get a new array (T, Y*X) where I have 'time' in the rows and 'pixel' in the colums

# Create an array full of NaN with the dimension of the number of pixels
slopes = np.full(ndvi_reshaped.shape[1], np.nan, dtype=np.float32)
pvals = np.full_like(slopes, np.nan, dtype=np.float32)

# Compute the linerar regression between NDVI and time for each pixel, and get the slope
for idx in range(ndvi_reshaped.shape[1]):
    y = ndvi_reshaped[:, idx]
    valid = np.isfinite(y)
    if np.sum(valid) > 2:
        slope, _, _, p, _ = linregress(time_numeric[valid], y[valid])
        slopes[idx] = slope
        pvals[idx] = p

# Reshape back to image
slope_map = slopes.reshape(Y, X)
pval_map = pvals.reshape(Y, X)

# Plot the Slope Map
plt.figure(figsize=(8, 6))
plt.imshow(slope_map, cmap='RdYlGn')
plt.colorbar(label='NDVI Trend (Slope)')
plt.title('NDVI Trend Map (Dry Season 2025 Guaranda)')
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# NDVI ANOMALY DETECTION (z-score anomaly for each date relative to the dry season mean)

mean_ndvi_map = ndvi.mean(dim="time", skipna=True)
std_ndvi_map = ndvi.std(dim='time', skipna=True)

# Anomaly: (ndvi_t - mean) / std
ndvi_anomaly = (ndvi - mean_ndvi_map)/std_ndvi_map

# Plot the anomaly for the first and last days of the period
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))

ndvi_anomaly.isel(time=0).plot(ax=ax1, cmap='RdBu', vmin=-2, vmax=2)
ax1.set_title(f"NDVI Anomaly ({str(ndvi['time'].values[0])[:10]})")

ndvi_anomaly.isel(time=-1).plot(ax=ax2, cmap='RdBu', vmin=-2, vmax=2)
ax2.set_title(f"NDVI Anomaly ({str(ndvi['time'].values[-1])[:10]})")

plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# c:\Users\Francesco\anaconda3\envs\env\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
# VEGETATION CHANGE HOTSPOT

# Data driven thresholds of NDVI changes
valid_slopes = slope_map[np.isfinite(slope_map)]
slope_std = np.std(valid_slopes)
slope_median = np.median(valid_slopes)
mad = np.median(abs(valid_slopes - slope_median))
sigma_thresh = 2 * slope_std
mad_thresh = 1.5 * mad
p90 = np.percentile(valid_slopes, 90)
p10 = np.percentile(valid_slopes, 10)
trend_thresh = p90 # the threshold can be chosen between sigma_thresh, mad_thresh, p90, p10

print(f"Std-based threshold: {sigma_thresh:.5f}")
print(f"MAD-based threshold: {mad_thresh:.5f}")
print(f"90th percentile: {p90:.5f}")
print(f"10th percentile: {p10:.5f}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Std-based threshold: 0.00662
# MAD-based threshold: 0.00136
# 90th percentile: 0.00203
# 10th percentile: -0.00196

# %%
# Vegetation mask (ndvi>=0.2 are vegetated pixels)
veg_mask = mean_ndvi_map >= 0.2

# Significance and trend test
alpha = 0.05
sig_mask = (pval_map < alpha) & veg_mask

hotspots = np.zeros_like(slope_map, dtype=np.int8)
hotspots[(slope_map > trend_thresh) & sig_mask] = 1  # Greening
hotspots[(slope_map < -trend_thresh) & sig_mask] = -1  # Browning

# Spatial cleanup
struct = generate_binary_structure(2, 2)
greening_clean = binary_opening(hotspots == 1, structure=struct)
browning_clean = binary_opening(hotspots == -1, structure=struct)
greening_clean = binary_closing(greening_clean, structure=struct)
browning_clean = binary_closing(browning_clean, structure=struct)

hotspots_clean = np.zeros_like(hotspots, dtype=np.int8)
hotspots_clean[greening_clean] = 1
hotspots_clean[browning_clean] = -1

# Visualization (4 plots)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(24, 6))

# Histogram of slopes
ax1.hist(valid_slopes, bins=100, color='gray', alpha=0.7)
ax1.axvline(p10, color='red', linestyle='--', label=f'10th pct = {p10:.5f}')
ax1.axvline(p90, color='green', linestyle='--', label=f'90th pct = {p90:.5f}')
ax1.axvline(-sigma_thresh, color='red', linestyle=':', label=f'-2σ = {-sigma_thresh:.5f}')
ax1.axvline(sigma_thresh, color='green', linestyle=':', label=f'+2σ = {sigma_thresh:.5f}')
ax1.set_title("Distribution of NDVI Slopes")
ax1.set_xlabel("NDVI Change per Day")
ax1.set_ylabel("Pixel Count")
ax1.legend()

# Hotspot map
im1 = ax2.imshow(hotspots_clean, cmap='RdYlGn', vmin=-1, vmax=1)
ax2.set_title('Vegetation Change Hotspots (Dry Season 2025 Guaranda)')
fig.colorbar(im1, ax=ax2, label='Trend (-1=Browning, 0=Stable, 1=Greening)')

# Mean NDVI map
im2 = ax3.imshow(mean_ndvi_map, cmap='YlGn', vmin=0, vmax=1)
ax3.set_title('Mean NDVI (Vegetation Mask Context)')
fig.colorbar(im2, ax=ax3, label='NDVI')

# p-value map (clip extreme values for visibility)
pval_display = np.clip(pval_map, 0, 0.1)
im3 = ax4.imshow(pval_display, cmap='viridis_r', vmin=0, vmax=0.1)
ax4.contour(sig_mask, levels=[0.5], colors='red', linewidths=0.8)
ax4.set_title('p-value map (red = significant, α = 0.05)')
fig.colorbar(im3, ax=ax4, label='p-value')

plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
